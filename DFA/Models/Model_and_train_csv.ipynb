# %%
#before running this please change the RUNTIME to GPU (Runtime -> Change runtime type -> set harware accelarotor as GPU)
#Mount our google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Note : Use the drive link for the processed dataset

# %%
#Note : only needed when you have to download the processed data to the environment
#download and unzip the data from google drive Colab environment
from google_drive_downloader import GoogleDriveDownloader as gdd
#use only file id of the link
#Note: Below link is just an example, Not an actual link. Actual Links are in ReadMe file
#https://drive.google.com/file/d/1ubvKLzBDe5i1acxgGUK6ObeNBYCKUS07/view?usp=sharing
url = '1ubvKLzBDe5i1acxgGUK6ObeNBYCKUS07'
gdd.download_file_from_google_drive(file_id = url,dest_path='./data.zip',unzip=True)
# Out:
# Downloading 1ubvKLzBDe5i1acxgGUK6ObeNBYCKUS07 into ./data.zip... Done.
# Unzipping...
# /usr/local/lib/python3.7/dist-packages/google_drive_downloader/google_drive_downloader.py:78: UserWarning: Ignoring `unzip` since "1ubvKLzBDe5i1acxgGUK6ObeNBYCKUS07" does not look like a valid zip file
#   warnings.warn('Ignoring `unzip` since "{}" does not look like a valid zip file'.format(file_id))

# %%
pip install face-recognition
# Out:
# Collecting face-recognition
#   Downloading face_recognition-1.3.0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.7/dist-packages (from face-recognition) (7.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from face-recognition) (1.21.5)
# Collecting face-recognition-models>=0.3.0
#   Downloading face_recognition_models-0.3.0.tar.gz (100.1 MB)
#      |████████████████████████████████| 100.1 MB 27 kB/s
# Requirement already satisfied: Click>=6.0 in /usr/local/lib/python3.7/dist-packages (from face-recognition) (7.1.2)
# Requirement already satisfied: dlib>=19.7 in /usr/local/lib/python3.7/dist-packages (from face-recognition) (19.18.0)
# Building wheels for collected packages: face-recognition-models
#   Building wheel for face-recognition-models (setup.py) ... done
#   Created wheel for face-recognition-models: filename=face_recognition_models-0.3.0-py2.py3-none-any.whl size=100566186 sha256=0109e3f5e0142acb50f0becdc6346152cd4ae8052321731565e94dd2a43da58a
#   Stored in directory: /root/.cache/pip/wheels/d6/81/3c/884bcd5e1c120ff548d57c2ecc9ebf3281c9a6f7c0e7e7947a
# Successfully built face-recognition-models
# Installing collected packages: face-recognition-models, face-recognition
# Successfully installed face-recognition-1.3.0 face-recognition-models-0.3.0

# %%
#THis code is to check if the video is corrupted or not..
#If the video is corrupted delete the video.
import glob
import torch
import torchvision
from torchvision import transforms
from torch.utils.data import DataLoader
from torch.utils.data.dataset import Dataset
import os
import numpy as np
import cv2
import matplotlib.pyplot as plt
import face_recognition
#Check if the file is corrupted or not
def validate_video(vid_path,train_transforms):
      transform = train_transforms
      count = 20
      video_path = vid_path
      frames = []
      a = int(100/count)
      first_frame = np.random.randint(0,a)
      temp_video = video_path.split('/')[-1]
      for i,frame in enumerate(frame_extract(video_path)):
        frames.append(transform(frame))
        if(len(frames) == count):
          break
      frames = torch.stack(frames)
      frames = frames[:count]
      return frames
#extract a from from video
def frame_extract(path):
  vidObj = cv2.VideoCapture(path) 
  success = 1
  while success:
      success, image = vidObj.read()
      if success:
          yield image

im_size = 112
mean = [0.485, 0.456, 0.406]
std = [0.229, 0.224, 0.225]

train_transforms = transforms.Compose([
                                        transforms.ToPILImage(),
                                        transforms.Resize((im_size,im_size)),
                                        transforms.ToTensor(),
                                        transforms.Normalize(mean,std)])
'''
video_fil =  glob.glob('/content/drive/My Drive/Celeb_fake_face_only/*.mp4')
video_fil += glob.glob('/content/drive/My Drive/Celeb_real_face_only/*.mp4')
video_fil += glob.glob('/content/drive/My Drive/DFDC_FAKE_Face_only_data/*.mp4')
video_fil += glob.glob('/content/drive/My Drive/DFDC_REAL_Face_only_data/*.mp4')
video_fil += glob.glob('/content/drive/My Drive/FF_Face_only_data/*.mp4')
'''
video_fil =  glob.glob('/content/drive/MyDrive/Colab/FinalFace_Data/*.mp4')

print("Total no of videos :" , len(video_fil))
print(video_fil)
count = 0;
for i in video_fil:
  try:
    count+=1
    validate_video(i,train_transforms)
  except:
    print("Number of video processed: " , count ," Remaining : " , (len(video_fil) - count))
    print("Corrupted video is : " , i)
    continue
print((len(video_fil) - count))
# Out:
# Total no of videos : 142
# ['/content/drive/MyDrive/Colab/FinalFace_Data/arlmiizoob.mp4', '/content/drive/MyDrive/Colab/FinalFace_Data/asaxgevnnp.mp4', '/content/drive/MyDrive/Colab/FinalFace_Data/aslsvlvpth.mp4', '/content/drive/MyDrive/Colab/FinalFace_Data/asdpeebotb.mp4', '/content/drive/MyDrive/Colab/FinalFace_Data/asmpfjfzif.mp4', '/content/drive/MyDrive/Colab/FinalFace_Data/arrhsnjqku.mp4', '/content/drive/MyDrive/Colab/FinalFace_Data/atvmxvwyns.mp4', '/content/drive/MyDrive/Colab/FinalFace_Data/atkdltyyen.mp4', '/content/drive/MyDrive/Colab/FinalFace_Data/asvcrfdpnq.mp4', '/content/drive/MyDrive/Colab/FinalFace_Data/atxvxouljq.mp4', '/content/drive/MyDrive/Colab/FinalFace_Data/atzdznmder.mp4', '/content/drive/MyDrive/Colab/FinalFace_Data/atyntldecu.mp4', '/content/drive/MyDrive/Colab/FinalFace_Data/aufmsmnoye.mp4', '/content/drive/MyDrive/Colab/FinalFace_Data/augtsuxpzc.mp4', '/content/drive/MyDrive/Colab/FinalFace_Data/avfitoutyn.mp4', '/content/drive/MyDrive/Colab/FinalFace_Data/avgiuextiz.mp4', '/content/drive/MyDrive/Colab/FinalFace_Data/avnqydkqjj.mp4', '/content/drive/MyDrive/Colab/FinalFace_Data/avmjormvsx.mp4', '/content/drive/MyDrive/Colab/FinalFace_Data/avibnnhwhp.mp4', '/content/drive/MyDrive/Colab/FinalFace_Data/avvdgsennp.mp4', '/content/drive/MyDrive/Colab/FinalFace_Data/avywawptfc.mp4', '/content/drive/MyDrive/Colab/FinalFace_Data/avtycwsgyb.mp4', '/content/drive/MyDrive/Colab/FinalFace_Data/awhmfnnjih.mp4', '/content/drive/MyDrive/Colab/FinalFace_Data/avssvvsdhz.mp4', '/content/drive/MyDrive/Colab/FinalFace_Data/awnwkrqibf.mp4', '/content/drive/MyDrive/Colab/FinalFace_Data/axczxisdtb.mp4', '/content/drive/MyDrive/Colab/FinalFace_Data/axntxmycwd.mp4', '/content/drive/MyDrive/Colab/FinalFace_Data/awukslzjra.mp4', '/content/drive/MyDrive/Colab/FinalFace_Data/axwovszumc.mp4', '/content/drive/MyDrive/Colab/FinalFace_Data/axoygtekut.mp4', '/content/drive/MyDrive/Colab/FinalFace_Data/axwgcsyphv.mp4', '/content/drive/MyDrive/Colab/FinalFace_Data/aybgughjxh.mp4', '/content/drive/MyDrive/Colab/FinalFace_Data/aytzyidmgs.mp4', '/content/drive/MyDrive/Colab/FinalFace_Data/azsmewqghg.mp4', '/content/drive/MyDrive/Colab/FinalFace_Data/azpuxunqyo.mp4', '/content/drive/MyDrive/Colab/FinalFace_Data/aybumesmpk.mp4', '/content/drive/MyDrive/Colab/FinalFace_Data/ayqvfdhslr.mp4', '/content/drive/MyDrive/Colab/FinalFace_Data/bahdpoesir.mp4', '/content/drive/MyDrive/Colab/FinalFace_Data/bbhpvrmbse.mp4', '/content/drive/MyDrive/Colab/FinalFace_Data/bbvgxeczei.mp4', '/content/drive/MyDrive/Colab/FinalFace_Data/bdbhekrrwo.mp4', '/content/drive/MyDrive/Colab/FinalFace_Data/bchnbulevv.mp4', '/content/drive/MyDrive/Colab/FinalFace_Data/bbhtdfuqxq.mp4', '/content/drive/MyDrive/Colab/FinalFace_Data/bctvsmddgq.mp4', '/content/drive/MyDrive/Colab/FinalFace_Data/bdnaqemxmr.mp4', '/content/drive/MyDrive/Colab/FinalFace_Data/bddjdhzfze.mp4', '/content/drive/MyDrive/Colab/FinalFace_Data/bdgipnyobr.mp4', '/content/drive/MyDrive/Colab/FinalFace_Data/benmsfzfaz.mp4', '/content/drive/MyDrive/Colab/FinalFace_Data/bdxuhamuqx.mp4', '/content/drive/MyDrive/Colab/FinalFace_Data/bejhvclboh.mp4', '/content/drive/MyDrive/Colab/FinalFace_Data/beboztfcme.mp4', '/content/drive/MyDrive/Colab/FinalFace_Data/beyebyhrph.mp4', '/content/drive/MyDrive/Colab/FinalFace_Data/bgaogsjehq.mp4', '/content/drive/MyDrive/Colab/FinalFace_Data/bffwsjxghk.mp4', '/content/drive/MyDrive/Colab/FinalFace_Data/bghphrsfxf.mp4', '/content/drive/MyDrive/Colab/FinalFace_Data/bgvhtpzknn.mp4', '/content/drive/MyDrive/Colab/FinalFace_Data/bggsurpgpr.mp4', '/content/drive/MyDrive/Colab/FinalFace_Data/bgmlwsoamc.mp4', '/content/drive/MyDrive/Colab/FinalFace_Data/bhpwpydzpo.mp4', '/content/drive/MyDrive/Colab/FinalFace_Data/bguwlyazau.mp4', '/content/drive/MyDrive/Colab/FinalFace_Data/bhaaboftbc.mp4', '/content/drive/MyDrive/Colab/FinalFace_Data/bhbdugnurr.mp4', '/content/drive/MyDrive/Colab/FinalFace_Data/bgwmmujlmc.mp4', '/content/drive/MyDrive/Colab/FinalFace_Data/bhsluedavd.mp4', '/content/drive/MyDrive/Colab/F ...
# Number of video processed:  7  Remaining :  135
# Corrupted video is :  /content/drive/MyDrive/Colab/FinalFace_Data/atvmxvwyns.mp4
# Number of video processed:  20  Remaining :  122
# Corrupted video is :  /content/drive/MyDrive/Colab/FinalFace_Data/avvdgsennp.mp4
# Number of video processed:  31  Remaining :  111
# Corrupted video is :  /content/drive/MyDrive/Colab/FinalFace_Data/axwgcsyphv.mp4
# Number of video processed:  40  Remaining :  102
# Corrupted video is :  /content/drive/MyDrive/Colab/FinalFace_Data/bbvgxeczei.mp4
# Number of video processed:  97  Remaining :  45
# Corrupted video is :  /content/drive/MyDrive/Colab/FinalFace_Data/bqkdbcqjvb.mp4
# Number of video processed:  138  Remaining :  4
# Corrupted video is :  /content/drive/MyDrive/Colab/FinalFace_Data/cdyakrxkia.mp4
# Number of video processed:  141  Remaining :  1
# Corrupted video is :  /content/drive/MyDrive/Colab/FinalFace_Data/cettndmvzl.mp4
# 0

# %%
#To load preprocessod video to memory
import json
import glob
import numpy as np
import cv2
import copy
import random
'''
video_files =  glob.glob('/content/drive/My Drive/Celeb_fake_face_only/*.mp4')
video_files += glob.glob('/content/drive/My Drive/Celeb_real_face_only/*.mp4')
video_files += glob.glob('/content/drive/My Drive/DFDC_FAKE_Face_only_data/*.mp4')
video_files += glob.glob('/content/drive/My Drive/DFDC_REAL_Face_only_data/*.mp4')
video_files += glob.glob('/content/drive/My Drive/FF_Face_only_data/*.mp4')
'''
video_files =  glob.glob('/content/drive/MyDrive/Colab/FinalFace_Data/*.mp4')


random.shuffle(video_files)
random.shuffle(video_files)
frame_count = []
for video_file in video_files:
  cap = cv2.VideoCapture(video_file)
  if(int(cap.get(cv2.CAP_PROP_FRAME_COUNT))<100):
    video_files.remove(video_file)
    continue
  frame_count.append(int(cap.get(cv2.CAP_PROP_FRAME_COUNT)))
print("frames are " , frame_count)
print("Total no of video: " , len(frame_count))
print('Average frame per video:',np.mean(frame_count))
# Out:
# frames are  [148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148]
# Total no of video:  128
# Average frame per video: 148.0

# %%
# load the video name and labels from csv
import torch
import torchvision
from torchvision import transforms
from torch.utils.data import DataLoader
from torch.utils.data.dataset import Dataset
import os
import numpy as np
import cv2
import matplotlib.pyplot as plt
import face_recognition
class video_dataset(Dataset):
    def __init__(self,video_names,labels,sequence_length = 60,transform = None):
        self.video_names = video_names
        self.labels = labels
        self.transform = transform
        self.count = sequence_length
    def __len__(self):
        return len(self.video_names)
    def __getitem__(self,idx):
        video_path = self.video_names[idx]
        frames = []
        a = int(100/self.count)
        first_frame = np.random.randint(0,a)
        temp_video = video_path.split('/')[-1]
        #print(temp_video)
        label = self.labels.iloc[(labels.loc[labels["_key"] == temp_video].index.values[0]),1]
        if(label == 'FAKE'):
          label = 0
        if(label == 'REAL'):
          label = 1
        for i,frame in enumerate(self.frame_extract(video_path)):
          frames.append(self.transform(frame))
          if(len(frames) == self.count):
            break
        frames = torch.stack(frames)
        frames = frames[:self.count]
        #
        print("length:" , len(frames), "label",label)
        return (frames,label)

    def frame_extract(self,path):
      vidObj = cv2.VideoCapture(path) 
      success = 1
      while success:
          success, image = vidObj.read()
          if success:
              yield image
#plot the image
def im_plot(tensor):
    image = tensor.cpu().numpy().transpose(1,2,0)
    b,g,r = cv2.split(image)
    image = cv2.merge((r,g,b))
    image = image*[0.22803, 0.22145, 0.216989] +  [0.43216, 0.394666, 0.37645]
    image = image*255.0
    plt.imshow(image.astype(int))
    plt.show()

# %%
#count the number of fake and real videos
def number_of_real_and_fake_videos(data_list):
  header_list = ["_key","label"]
  lab = pd.read_csv('/content/drive/MyDrive/Colab/metadata.csv',usecols=header_list)
  
  fake = 0
  real = 0
  for i in data_list:
    temp_video = i.split('/')[-1]
    label = lab.iloc[(lab.loc[lab["_key"] == temp_video].index.values[0]),1]
    if(label == 'FAKE'):
      fake+=1
    if(label == 'REAL'):
      real+=1
  return real,fake

# %%
# load the labels and video in data loader
import random
import pandas as pd
from sklearn.model_selection import train_test_split

header_list = ["_key","label"]
#labels = pd.read_csv('/content/drive/My Drive/Gobal_metadata.csv',names=header_list)
labels = pd.read_csv('/content/drive/MyDrive/Colab/metadata.csv',usecols=header_list)
# print(labels)
train_videos = video_files[:int(0.8*len(video_files))]
valid_videos = video_files[int(0.8*len(video_files)):]
print("train : " , len(train_videos))
print("test : " , len(valid_videos))
# train_videos,valid_videos = train_test_split(data,test_size = 0.2)
# print(train_videos)
a1 = number_of_real_and_fake_videos(train_videos)
a2 = number_of_real_and_fake_videos(valid_videos)
print("TRAIN: ", "Real:",a1[0]," Fake:",a1[1])
print("TEST: ", "Real:",a2[0]," Fake:",a2[1])
print('----------------------')
im_size = 112
mean = [0.485, 0.456, 0.406]
std = [0.229, 0.224, 0.225]

train_transforms = transforms.Compose([
                                        transforms.ToPILImage(),
                                        transforms.Resize((im_size,im_size)),
                                        transforms.ToTensor(),
                                        transforms.Normalize(mean,std)])

test_transforms = transforms.Compose([
                                        transforms.ToPILImage(),
                                        transforms.Resize((im_size,im_size)),
                                        transforms.ToTensor(),
                                        transforms.Normalize(mean,std)])
train_data = video_dataset(train_videos,labels,sequence_length = 10,transform = train_transforms)
val_data = video_dataset(valid_videos,labels,sequence_length = 10,transform = train_transforms)
train_loader = DataLoader(train_data,batch_size = 4,shuffle = True,num_workers = 4)
valid_loader = DataLoader(val_data,batch_size = 4,shuffle = True,num_workers = 4)
# Out:
# train :  108
# test :  27
# TRAIN:  Real: 23  Fake: 85
# TEST:  Real: 3  Fake: 24
# ----------------------
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %%
#Model with feature visualization
from torch import nn
from torchvision import models
class Model(nn.Module):
    def __init__(self, num_classes,latent_dim= 2048, lstm_layers=1 , hidden_dim = 2048, bidirectional = False):
        super(Model, self).__init__()
        model = models.resnext50_32x4d(pretrained = True) #Residual Network CNN
        self.model = nn.Sequential(*list(model.children())[:-2])
        self.lstm = nn.LSTM(latent_dim,hidden_dim, lstm_layers,  bidirectional)
        self.relu = nn.LeakyReLU()
        self.dp = nn.Dropout(0.4)
        self.linear1 = nn.Linear(2048,num_classes)
        self.avgpool = nn.AdaptiveAvgPool2d(1)
    def forward(self, x):
        batch_size,seq_length, c, h, w = x.shape
        x = x.view(batch_size * seq_length, c, h, w)
        fmap = self.model(x)
        x = self.avgpool(fmap)
        x = x.view(batch_size,seq_length,2048)
        x_lstm,_ = self.lstm(x,None)
        return fmap,self.dp(self.linear1(torch.mean(x_lstm,dim = 1)))

# %%
model = Model(2).cuda()
a,b = model(torch.from_numpy(np.empty((1,20,3,112,112))).type(torch.cuda.FloatTensor))
# Out:
# Exception in thread QueueFeederThread:
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/multiprocessing/queues.py", line 232, in _feed
#     close()
#   File "/usr/lib/python3.7/multiprocessing/connection.py", line 177, in close
#     self._close()
#   File "/usr/lib/python3.7/multiprocessing/connection.py", line 361, in _close
#     _close(self._handle)
# OSError: [Errno 9] Bad file descriptor
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.7/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.7/multiprocessing/queues.py", line 263, in _feed
#     queue_sem.release()
# ValueError: semaphore or lock released too many times

# %%
import torch
from torch.autograd import Variable
import time
import os
import sys
import os
def train_epoch(epoch, num_epochs, data_loader, model, criterion, optimizer):
    model.train()
    losses = AverageMeter()
    accuracies = AverageMeter()
    t = []
    for i, (inputs, targets) in enumerate(data_loader):
        if torch.cuda.is_available():
            targets = targets.type(torch.cuda.LongTensor)
            inputs = inputs.cuda()
        _,outputs = model(inputs)
        loss  = criterion(outputs,targets.type(torch.cuda.LongTensor))
        acc = calculate_accuracy(outputs, targets.type(torch.cuda.LongTensor))
        losses.update(loss.item(), inputs.size(0))
        accuracies.update(acc, inputs.size(0))
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        sys.stdout.write(
                "\r[Epoch %d/%d] [Batch %d / %d] [Loss: %f, Acc: %.2f%%]"
                % (
                    epoch,
                    num_epochs,
                    i,
                    len(data_loader),
                    losses.avg,
                    accuracies.avg))
    torch.save(model.state_dict(),'/content/drive/MyDrive/Colab/Trained_Model/checkpoint.pt')
    return losses.avg,accuracies.avg
def test(epoch,model, data_loader ,criterion):
    print('Testing')
    model.eval()
    losses = AverageMeter()
    accuracies = AverageMeter()
    pred = []
    true = []
    count = 0
    with torch.no_grad():
        for i, (inputs, targets) in enumerate(data_loader):
            if torch.cuda.is_available():
                targets = targets.cuda().type(torch.cuda.FloatTensor)
                inputs = inputs.cuda()
            _,outputs = model(inputs)
            loss = torch.mean(criterion(outputs, targets.type(torch.cuda.LongTensor)))
            acc = calculate_accuracy(outputs,targets.type(torch.cuda.LongTensor))
            _,p = torch.max(outputs,1) 
            true += (targets.type(torch.cuda.LongTensor)).detach().cpu().numpy().reshape(len(targets)).tolist()
            pred += p.detach().cpu().numpy().reshape(len(p)).tolist()
            losses.update(loss.item(), inputs.size(0))
            accuracies.update(acc, inputs.size(0))
            sys.stdout.write(
                    "\r[Batch %d / %d]  [Loss: %f, Acc: %.2f%%]"
                    % (
                        i,
                        len(data_loader),
                        losses.avg,
                        accuracies.avg
                        )
                    )
        print('\nAccuracy {}'.format(accuracies.avg))
    return true,pred,losses.avg,accuracies.avg
class AverageMeter(object):
    """Computes and stores the average and current value"""
    def __init__(self):
        self.reset()
    def reset(self):
        self.val = 0
        self.avg = 0
        self.sum = 0
        self.count = 0

    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count
def calculate_accuracy(outputs, targets):
    batch_size = targets.size(0)

    _, pred = outputs.topk(1, 1, True)
    pred = pred.t()
    correct = pred.eq(targets.view(1, -1))
    n_correct_elems = correct.float().sum().item()
    return 100* n_correct_elems / batch_size

# %%
import seaborn as sn
#Output confusion matrix
def print_confusion_matrix(y_true, y_pred):
    cm = confusion_matrix(y_true, y_pred)
    print('True positive = ', cm[0][0])
    print('False positive = ', cm[0][1])
    print('False negative = ', cm[1][0])
    print('True negative = ', cm[1][1])
    print('\n')
    df_cm = pd.DataFrame(cm, range(2), range(2))
    sn.set(font_scale=1.4) # for label size
    sn.heatmap(df_cm, annot=True, annot_kws={"size": 16}) # font size
    plt.ylabel('Actual label', size = 20)
    plt.xlabel('Predicted label', size = 20)
    plt.xticks(np.arange(2), ['Fake', 'Real'], size = 16)
    plt.yticks(np.arange(2), ['Fake', 'Real'], size = 16)
    plt.ylim([2, 0])
    plt.show()
    calculated_acc = (cm[0][0]+cm[1][1])/(cm[0][0]+cm[0][1]+cm[1][0]+ cm[1][1])
    print("Calculated Accuracy",calculated_acc*100)

# %%
def plot_loss(train_loss_avg,test_loss_avg,num_epochs):
  loss_train = train_loss_avg
  loss_val = test_loss_avg
  print(num_epochs)
  epochs = range(1,num_epochs+1)
  plt.plot(epochs, loss_train, 'g', label='Training loss')
  plt.plot(epochs, loss_val, 'b', label='validation loss')
  plt.title('Training and Validation loss')
  plt.xlabel('Epochs')
  plt.ylabel('Loss')
  plt.legend()
  plt.show()
def plot_accuracy(train_accuracy,test_accuracy,num_epochs):
  loss_train = train_accuracy
  loss_val = test_accuracy
  epochs = range(1,num_epochs+1)
  plt.plot(epochs, loss_train, 'g', label='Training accuracy')
  plt.plot(epochs, loss_val, 'b', label='validation accuracy')
  plt.title('Training and Validation accuracy')
  plt.xlabel('Epochs')
  plt.ylabel('Accuracy')
  plt.legend()
  plt.show()

# %%
from sklearn.metrics import confusion_matrix

#learning rate
lr = 1e-5#0.001
#number of epochs 
num_epochs = 20

optimizer = torch.optim.Adam(model.parameters(), lr= lr,weight_decay = 1e-5)

#class_weights = torch.from_numpy(np.asarray([1,15])).type(torch.FloatTensor).cuda()
#criterion = nn.CrossEntropyLoss(weight = class_weights).cuda()
criterion = nn.CrossEntropyLoss().cuda()
train_loss_avg =[]
train_accuracy = []
test_loss_avg = []
test_accuracy = []
for epoch in range(1,num_epochs+1):
    l, acc = train_epoch(epoch,num_epochs,train_loader,model,criterion,optimizer)
    train_loss_avg.append(l)
    train_accuracy.append(acc)
    true,pred,tl,t_acc = test(epoch,model,valid_loader,criterion)
    test_loss_avg.append(tl)
    test_accuracy.append(t_acc)
plot_loss(train_loss_avg,test_loss_avg,len(train_loss_avg))
plot_accuracy(train_accuracy,test_accuracy,len(train_accuracy))
print(confusion_matrix(true,pred))
print_confusion_matrix(true,pred)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 1
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 1
# length: 10 label 0
# length: 10 label 0
# length: 10 label 1
# length: 10 label 1
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 1
# length: 10 label 1
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 1
# length: 10 label 1
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 1
# length: 10 label 1
# length: 10 label 0
# [Epoch 1/20] [Batch 0 / 27] [Loss: 0.519886, Acc: 100.00%]length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# [Epoch 1/20] [Batch 1 / 27] [Loss: 0.348668, Acc: 100.00%]length: 10 label 0
# length: 10 label 0
# length: 10 label 1
# length: 10 label 0
# [Epoch 1/20] [Batch 2 / 27] [Loss: 0.233978, Acc: 100.00%]length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 1
# [Epoch 1/20] [Batch 3 / 27] [Loss: 0.219957, Acc: 100.00%]length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# [Epoch 1/20] [Batch 4 / 27] [Loss: 0.179058, Acc: 100.00%]length: 10 label 0
# length: 10 label 0
# length: 10 label 1
# length: 10 label 1
# [Epoch 1/20] [Batch 5 / 27] [Loss: 0.180226, Acc: 100.00%]length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# [Epoch 1/20] [Batch 6 / 27] [Loss: 0.180136, Acc: 100.00%]length: 10 label 0
# length: 10 label 0
# length: 10 label 1
# length: 10 label 1
# [Epoch 1/20] [Batch 7 / 27] [Loss: 0.222602, Acc: 96.88%]length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# [Epoch 1/20] [Batch 8 / 27] [Loss: 0.204278, Acc: 97.22%]length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# [Epoch 1/20] [Batch 9 / 27] [Loss: 0.201934, Acc: 97.50%]length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# [Epoch 1/20] [Batch 10 / 27] [Loss: 0.199491, Acc: 97.73%]length: 10 label 0
# length: 10 label 0
# length: 10 label 1
# length: 10 label 0
# [Epoch 1/20] [Batch 11 / 27] [Loss: 0.197348, Acc: 97.92%]length: 10 label 0
# length: 10 label 0
# length: 10 label 1
# length: 10 label 0
# [Epoch 1/20] [Batch 12 / 27] [Loss: 0.208844, Acc: 96.15%]length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 1
# [Epoch 1/20] [Batch 13 / 27] [Loss: 0.193928, Acc: 96.43%]length: 10 label 0
# length: 10 label 0
# length: 10 label 1
# length: 10 label 0
# [Epoch 1/20] [Batch 14 / 27] [Loss: 0.204364, Acc: 95.00%]length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# [Epoch 1/20] [Batch 15 / 27] [Loss: 0.191594, Acc: 95.31%]length: 10 label 1
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# [Epoch 1/20] [Batch 16 / 27] [Loss: 0.190517, Acc: 94.12%]length: 10 label 0
# length: 10 label 0
# length: 10 label 1
# length: 10 label 1
# [Epoch 1/20] [Batch 26 / 27] [Loss: 0.182094, Acc: 92.59%]Testing
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 1
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 1
# length: 10 label 0
# length: 10 label 0
# length: 10 label 1
# length: 10 label 0
# [Batch 6 / 7]  [Loss: 0.431258, Acc: 85.19%]
# Accuracy 85.18518518518519
# length: 10 label 1
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 1
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 1
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 1
# length: 10 label 1
# length: 10 label 0
# length: 10 label 0
# length: 10 label 1
# length: 10 label 1
# length: 10 label 1
# length: 10 label 0
# length: 10 label 1
# length: 10 label 0
# length: 10 label 1
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# [Epoch 2/20] [Batch 0 / 27] [Loss: 0.181029, Acc: 100.00%]length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# [Epoch 2/20] [Batch 1 / 27] [Loss: 0.093063, Acc: 100.00%]length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# [Epoch 2/20] [Batch 2 / 27] [Loss: 0.066822, Acc: 100.00%]length: 10 label 0
# length: 10 label 0
# length: 10 label 1
# length: 10 label 0
# [Epoch 2/20] [Batch 3 / 27] [Loss: 0.136848, Acc: 93.75%]length: 10 label 0
# length: 10 label 1
# length: 10 label 0
# length: 10 label 1
# [Epoch 2/20] [Batch 4 / 27] [Loss: 0.109790, Acc: 95.00%]length: 10 label 0
# length: 10 label 0
# length: 10 label 1
# length: 10 label 0
# [Epoch 2/20] [Batch 5 / 27] [Loss: 0.093759, Acc: 95.83%]length: 10 label 0
# length: 10 label 0
# length: 10 label 1
# length: 10 label 0
# [Epoch 2/20] [Batch 6 / 27] [Loss: 0.130064, Acc: 96.43%]length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# [Epoch 2/20] [Batch 7 / 27] [Loss: 0.328433, Acc: 93.75%]length: 10 label 0
# length: 10 label 0
# length: 10 label 1
# length: 10 label 0
# [Epoch 2/20] [Batch 8 / 27] [Loss: 0.292141, Acc: 94.44%]length: 10 label 1
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# [Epoch 2/20] [Batch 9 / 27] [Loss: 0.281842, Acc: 95.00%]length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# [Epoch 2/20] [Batch 10 / 27] [Loss: 0.272648, Acc: 95.45%]length: 10 label 0
# length: 10 label 1
# length: 10 label 0
# length: 10 label 0
# [Epoch 2/20] [Batch 11 / 27] [Loss: 0.251410, Acc: 95.83%]length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 1
# [Epoch 2/20] [Batch 12 / 27] [Loss: 0.245413, Acc: 94.23%]length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# [Epoch 2/20] [Batch 13 / 27] [Loss: 0.228458, Acc: 94.64%]length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 1
# length: 10 label 0
# [Epoch 2/20] [Batch 14 / 27] [Loss: 0.224892, Acc: 95.00%]length: 10 label 0
# length: 10 label 1
# length: 10 label 0
# length: 10 label 0
# [Epoch 2/20] [Batch 15 / 27] [Loss: 0.211143, Acc: 95.31%]length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 1
# [Epoch 2/20] [Batch 16 / 27] [Loss: 0.198785, Acc: 95.59%]length: 10 label 0
# length: 10 label 1
# length: 10 label 0
# length: 10 label 0
# [Epoch 2/20] [Batch 26 / 27] [Loss: 0.162170, Acc: 96.30%]Testing
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 1
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 1
# length: 10 label 0
# length: 10 label 0
# length: 10 label 1
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# [Batch 6 / 7]  [Loss: 0.521893, Acc: 81.48%]
# Accuracy 81.48148148148148
# length: 10 label 0
# length: 10 label 1
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 1
# length: 10 label 1
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 1
# length: 10 label 1
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 1
# length: 10 label 1
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 1
# length: 10 label 0
# length: 10 label 0
# length: 10 label 1
# length: 10 label 0
# length: 10 label 1
# length: 10 label 1
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# [Epoch 3/20] [Batch 0 / 27] [Loss: 0.007825, Acc: 100.00%]length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 1
# [Epoch 3/20] [Batch 1 / 27] [Loss: 0.091496, Acc: 100.00%]length: 10 label 1
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# [Epoch 3/20] [Batch
]length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# [Epoch 18/20] [Batch 13 / 27] [Loss: 0.101818, Acc: 98.21%]length: 10 label 1
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# [Epoch 18/20] [Batch 14 / 27] [Loss: 0.106656, Acc: 98.33%]length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# [Epoch 18/20] [Batch 15 / 27] [Loss: 0.112181, Acc: 98.44%]length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# [Epoch 18/20] [Batch 16 / 27] [Loss: 0.105805, Acc: 98.53%]length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 1
# [Epoch 18/20] [Batch 26 / 27] [Loss: 0.105490, Acc: 98.15%]Testing
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 1
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 1
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 1
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# [Batch 6 / 7]  [Loss: 0.358091, Acc: 92.59%]
# Accuracy 92.5925925925926
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 1
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 1
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 1
# length: 10 label 0
# length: 10 label 1
# length: 10 label 1
# length: 10 label 0
# length: 10 label 1
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 1
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# [Epoch 19/20] [Batch 0 / 27] [Loss: 0.226737, Acc: 100.00%]length: 10 label 0
# length: 10 label 0
# length: 10 label 1
# length: 10 label 0
# [Epoch 19/20] [Batch 1 / 27] [Loss: 0.113643, Acc: 100.00%]length: 10 label 1
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# [Epoch 19/20] [Batch 2 / 27] [Loss: 0.076242, Acc: 100.00%]length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# [Epoch 19/20] [Batch 3 / 27] [Loss: 0.100855, Acc: 100.00%]length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# [Epoch 19/20] [Batch 4 / 27] [Loss: 0.115466, Acc: 100.00%]length: 10 label 0
# length: 10 label 0
# length: 10 label 1
# length: 10 label 0
# [Epoch 19/20] [Batch 5 / 27] [Loss: 0.097416, Acc: 100.00%]length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# [Epoch 19/20] [Batch 6 / 27] [Loss: 0.083728, Acc: 100.00%]length: 10 label 1
# length: 10 label 1
# length: 10 label 0
# length: 10 label 0
# [Epoch 19/20] [Batch 7 / 27] [Loss: 0.073335, Acc: 100.00%]length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# [Epoch 19/20] [Batch 8 / 27] [Loss: 0.084945, Acc: 100.00%]length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 1
# [Epoch 19/20] [Batch 9 / 27] [Loss: 0.076598, Acc: 100.00%]length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# [Epoch 19/20] [Batch 10 / 27] [Loss: 0.069714, Acc: 100.00%]length: 10 label 0
# length: 10 label 1
# length: 10 label 0
# length: 10 label 1
# [Epoch 19/20] [Batch 11 / 27] [Loss: 0.064072, Acc: 100.00%]length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# [Epoch 19/20] [Batch 12 / 27] [Loss: 0.059811, Acc: 100.00%]length: 10 label 1
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# [Epoch 19/20] [Batch 13 / 27] [Loss: 0.055738, Acc: 100.00%]length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# [Epoch 19/20] [Batch 14 / 27] [Loss: 0.063586, Acc: 98.33%]length: 10 label 1
# length: 10 label 0
# length: 10 label 0
# length: 10 label 1
# [Epoch 19/20] [Batch 15 / 27] [Loss: 0.060245, Acc: 98.44%]length: 10 label 1
# length: 10 label 1
# length: 10 label 1
# length: 10 label 0
# length: 10 label 1
# [Epoch 19/20] [Batch 16 / 27] [Loss: 0.057216, Acc: 98.53%]length: 10 label 0
# length: 10 label 0
# length: 10 label 1
# length: 10 label 0
# [Epoch 19/20] [Batch 26 / 27] [Loss: 0.078026, Acc: 98.15%]Testing
# length: 10 label 0
# length: 10 label 1
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 1
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 1
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# [Batch 6 / 7]  [Loss: 0.440728, Acc: 92.59%]
# Accuracy 92.5925925925926
# length: 10 label 1
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 1
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 1
# length: 10 label 1
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 1
# length: 10 label 0
# length: 10 label 1
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 1
# length: 10 label 1
# length: 10 label 0
# [Epoch 20/20] [Batch 0 / 27] [Loss: 0.175330, Acc: 100.00%]length: 10 label 0
# length: 10 label 1
# length: 10 label 0
# length: 10 label 0
# [Epoch 20/20] [Batch 1 / 27] [Loss: 0.088792, Acc: 100.00%]length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# [Epoch 20/20] [Batch 2 / 27] [Loss: 0.061230, Acc: 100.00%]length: 10 label 0
# length: 10 label 1
# length: 10 label 0
# length: 10 label 1
# [Epoch 20/20] [Batch 3 / 27] [Loss: 0.046128, Acc: 100.00%]length: 10 label 0
# length: 10 label 1
# length: 10 label 0
# length: 10 label 0
# [Epoch 20/20] [Batch 4 / 27] [Loss: 0.107832, Acc: 95.00%]length: 10 label 0
# length: 10 label 1
# length: 10 label 1
# length: 10 label 0
# [Epoch 20/20] [Batch 5 / 27] [Loss: 0.119204, Acc: 95.83%]length: 10 label 0
# length: 10 label 1
# length: 10 label 0
# length: 10 label 0
# [Epoch 20/20] [Batch 6 / 27] [Loss: 0.103293, Acc: 96.43%]length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# [Epoch 20/20] [Batch 7 / 27] [Loss: 0.112044, Acc: 96.88%]length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# [Epoch 20/20] [Batch 8 / 27] [Loss: 0.118942, Acc: 97.22%]length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# [Epoch 20/20] [Batch 9 / 27] [Loss: 0.107075, Acc: 97.50%]length: 10 label 0
# length: 10 label 0
# length: 10 label 1
# length: 10 label 0
# [Epoch 20/20] [Batch 10 / 27] [Loss: 0.113117, Acc: 95.45%]length: 10 label 1
# length: 10 label 0
# length: 10 label 1
# length: 10 label 0
# [Epoch 20/20] [Batch 11 / 27] [Loss: 0.118302, Acc: 95.83%]length: 10 label 0
# length: 10 label 0
# length: 10 label 1
# length: 10 label 0
# [Epoch 20/20] [Batch 12 / 27] [Loss: 0.123650, Acc: 94.23%]length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# [Epoch 20/20] [Batch 13 / 27] [Loss: 0.128277, Acc: 92.86%]length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# [Epoch 20/20] [Batch 14 / 27] [Loss: 0.143484, Acc: 93.33%]length: 10 label 1
# length: 10 label 1
# length: 10 label 0
# length: 10 label 0
# [Epoch 20/20] [Batch 15 / 27] [Loss: 0.145364, Acc: 93.75%]length: 10 label 0
# length: 10 label 1
# length: 10 label 0
# length: 10 label 1
# [Epoch 20/20] [Batch 16 / 27] [Loss: 0.136814, Acc: 94.12%]length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# [Epoch 20/20] [Batch 26 / 27] [Loss: 0.132712, Acc: 92.59%]Testing
# length: 10 label 1
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 1
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 0
# length: 10 label 1
# length: 10 label 0
# [Batch 6 / 7]  [Loss: 0.521946, Acc: 92.59%]
# Accuracy 92.5925925925926
# 20
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/multiprocessing/queues.py", line 232, in _feed
#     close()
#   File "/usr/lib/python3.7/multiprocessing/connection.py", line 177, in close
#     self._close()
#   File "/usr/lib/python3.7/multiprocessing/connection.py", line 361, in _close
#     _close(self._handle)
# OSError: [Errno 9] Bad file descriptor
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/multiprocessing/queues.py", line 242, in _feed
#     send_bytes(obj)
#   File "/usr/lib/python3.7/multiprocessing/connection.py", line 200, in send_bytes
#     self._send_bytes(m[offset:offset + size])
#   File "/usr/lib/python3.7/multiprocessing/connection.py", line 404, in _send_bytes
#     self._send(header + buf)
#   File "/usr/lib/python3.7/multiprocessing/connection.py", line 368, in _send
#     n = write(self._handle, buf)
# OSError: [Errno 9] Bad file descriptor
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/multiprocessing/queues.py", line 232, in _feed
#     close()
#   File "/usr/lib/python3.7/multiprocessing/connection.py", line 177, in close
#     self._close()
#   File "/usr/lib/python3.7/multiprocessing/connection.py", line 361, in _close
#     _close(self._handle)
# OSError: [Errno 9] Bad file descriptor
# Exception in thread QueueFeederThread:
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/multiprocessing/queues.py", line 232, in _feed
#     close()
#   File "/usr/lib/python3.7/multiprocessing/connection.py", line 177, in close
#     self._close()
#   File "/usr/lib/python3.7/multiprocessing/connection.py", line 361, in _close
#     _close(self._handle)
# OSError: [Errno 9] Bad file descriptor
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.7/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.7/multiprocessing/queues.py", line 263, in _feed
#     queue_sem.release()
# ValueError: semaphore or lock released too many times
#
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/multiprocessing/queues.py", line 242, in _feed
#     send_bytes(obj)
#   File "/usr/lib/python3.7/multiprocessing/connection.py", line 200, in send_bytes
#     self._send_bytes(m[offset:offset + size])
#   File "/usr/lib/python3.7/multiprocessing/connection.py", line 404, in _send_bytes
#     self._send(header + buf)
#   File "/usr/lib/python3.7/multiprocessing/connection.py", line 368, in _send
#     n = write(self._handle, buf)
# BrokenPipeError: [Errno 32] Broken pipe
# Exception in thread QueueFeederThread:
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/multiprocessing/queues.py", line 232, in _feed
#     close()
#   File "/usr/lib/python3.7/multiprocessing/connection.py", line 177, in close
#     self._close()
#   File "/usr/lib/python3.7/multiprocessing/connection.py", line 361, in _close
#     _close(self._handle)
# OSError: [Errno 9] Bad file descriptor
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.7/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.7/multiprocessing/queues.py", line 263, in _feed
#     queue_sem.release()
# ValueError: semaphore or lock released too many times
# [[23  1]
#  [ 1  2]]
# True positive =  23
# False positive =  1
# False negative =  1
# True negative =  2
# Calculated Accuracy 92.5925925925926
